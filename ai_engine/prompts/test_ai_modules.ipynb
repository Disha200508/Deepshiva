# %%
from tourism_rag import answer_tourism_rag
print(answer_tourism_rag("Best places to visit in Rajasthan in December?"))
# Out:
# Rajasthan in December is a wonderful idea. The weather is pleasant, with average temperatures ranging from 10°C to 20°C, making it ideal for exploring the state's rich heritage and culture. Here are some of the best places to visit in Rajasthan in December:
#
# 1. **Jaipur**: The Pink City is a must-visit in December, with its stunning forts, palaces, and vibrant markets. Don't miss the Amber Fort, City Palace, and Hawa Mahal. Source: tour_1
# 2. **Jaisalmer**: This golden city is a great destination in December, with its majestic Jaisalmer Fort, intricately carved havelis, and sprawling Thar Desert. You can also enjoy a camel safari or camping under the stars. Source: tour_12, tour_82
# 3. **Udaipur**: Known as the City of Lakes, Udaipur is a beautiful destination in December, with its picturesque lakes, temples, and palaces. Visit the City Palace, Lake Pichola, and Jag Mandir for a memorable experience.
# ...

# %%
from spiritual_rag import answer_spiritual_rag
print(answer_spiritual_rag("What is the significance of Kedarnath?"))
# Out:
# My child, let us embark on a spiritual journey to the revered temple of Kedarnath, one of the twelve Jyotirlingas and a sacred part of the Char Dham Yatra. Located in the Garhwal Himalayas, Kedarnath is a testament to the divine presence of Lord Shiva.
#
# The mythology surrounding Kedarnath is deeply rooted in the Mahabharata. It is said that the Pandavas, after winning the battle of Kurukshetra, sought to atone for their sins by performing a pilgrimage to Kedarnath. According to legend, Lord Shiva, pleased with their devotion, appeared before them in the form of a bull, and the hump of the bull is worshipped as the Kedarnath shrine.
#
# The deity worshipped at Kedarnath is Lord Shiva, in the form of a linga. The temple's architecture is a marvel, with intricate carvings and sculptures that adorn its walls. The rituals performed at Kedarnath include the daily puja, abhishekam, and aarti, which are steeped in tradition and spiritual significance.
#
# ...

# %%
from router import ai_router
ai_router("What is the significance of Kedarnath?")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Detected intent: spiritual
# ...

# %%
ai_router("Best places to visit in Rajasthan?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("What is the significance of Kedarnath?")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("Am I doing yoga correctly?")
# Out:
# Detected intent: yoga
# 'Please upload a yoga pose image.'

# %%
from tourism_rag import answer_tourism_rag
print(answer_tourism_rag("Best places to visit in Dehradun in December?"))
# Out:
# Dehradun in December is a wonderful idea. The weather is cool and pleasant, making it perfect for exploring the city. Here are some of the best places to visit in Dehradun in December:
#
# 1. **Robber's Cave** (Guchhupani): A natural cave with a river flowing through it, making it a great spot for a winter picnic. Source: tour_13
# 2. **Mindrolling Monastery**: A beautiful Buddhist monastery with stunning architecture and peaceful surroundings. It's a great place to learn about Tibetan culture and history.
# 3. **Forest Research Institute**: A historic institution with a stunning building and a museum showcasing the history of forestry in India.
# 4. **Wadia Institute of Himalayan Geology**: A great place to learn about the geology of the Himalayas and see some amazing rock formations.
# 5. **Sahastradhara**: A scenic spot with a beautiful waterfall and a sulfur spring, making it a great place to relax and unwind.
# ...

# %%
ai_router("What is the significance of Kainchi Dham?")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("What is the significance of Purnagiri?")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("What is the significance of Haat Kalika?")
# Out:
# Detected intent: spiritual
# ...

# %%
from tourism_rag import answer_tourism_rag
print(answer_tourism_rag("Best places to visit in Champawat in December?"))
# Out:
# Champawat जैसे सुंदर स्थान पर जाने के लिए दिसंबर एक अच्छा समय है! Champawat, उत्तराखंड में स्थित, अपने प्राकृतिक सौंदर्य और ऐतिहासिक महत्व के लिए जाना जाता है। दिसंबर में, यहाँ का मौसम ठंडा और सुहावना होता है, जो पर्यटन के लिए उपयुक्त है।
#
# चंपावत में दिसंबर में घूमने के लिए कुछ सबसे अच्छे स्थान हैं:
#
# 1. **बालेश्वर मंदिर**: यह एक प्राचीन शिव मंदिर है, जो अपने स्थापत्य और ऐतिहासिक महत्व के लिए प्रसिद्ध है। Source: tour_5 (हिमाचल प्रदेश के बजाय, यह उत्तराखंड में स्थित है)
# 2. **चंपावती देवी मंदिर**: यह मंदिर देवी चंपावती को समर्पित है, जो एक हिंदू देवी हैं। यह मंदिर अपने सुंदर वास्तुकला और शांत वातावरण के लिए जाना जाता है।
# 3. **लोहाघाट**: यह एक सुंदर हिल स्टेशन है, जो अपने प्राकृतिक सौंदर्य और ट्रेकिंग मार्गों के लिए प्रसिद्ध है। दिसंबर में, यहाँ का मौसम ठंडा और सुहावना होता है, जो ट्रेकिंग के लिए उपयुक्त है।
#
# दिसंबर में चंपावत जाने के लिए कुछ उपयोगी सुझाव हैं:
#
# * गर्म कपड़े ले जाना न भूलें, क्योंकि दिसंबर में यहाँ का मौसम ठंडा होता है।
# ...

# %%
ai_router("Best places to visit in Rajasthan?")
# Out:
# Detected intent: tourism
# ...

# %%
from router import ai_router
print(ai_router("Best places to visit in Rajasthan?"))
# Out:
# Detected intent: tourism
# Rajasthan! The land of kings, rich in history, culture, and natural beauty. There are numerous amazing places to visit in Rajasthan. Here are some of the top recommendations:
#
# 1. **Jaipur**: The Pink City, famous for its stunning architecture, vibrant markets, and historic landmarks like Amber Fort (Source: tour_1). Don't miss the Hawa Mahal, City Palace, and Jantar Mantar.
# 2. **Jaisalmer**: The Golden City, known for its majestic Jaisalmer Fort, which shines like gold in the desert sun (Source: tour_92, tour_102). Take a camel safari, explore the narrow streets, and enjoy the scenic views of the Thar Desert.
# 3. **Udaipur**: The City of Lakes, famous for its picturesque lakes, palaces, and temples. Visit the Lake Pichola, City Palace, and Jag Mandir for a regal experience.
# 4. **Jodhpur**: The Blue City, known for its blue-painted houses, majestic Mehrangarh Fort, and bustling markets. Don't miss the Umaid Bhawan Palace and Jaswant Thada.
# ...

# %%
print(ai_router("Tell me a story"))
# Out:
# Detected intent: general
# Namaste, my friend. I'm delighted to share a story with you, one that's deeply rooted in the rich cultural heritage of our beloved India. Gather 'round, and let me transport you to the majestic Himalayas, where the air is crisp, and the spirit is free.
#
# It's a tale of the Char Dham, the four sacred abodes of the divine, nestled in the Garhwal region of Uttarakhand. You see, my friend, these four shrines – Badrinath, Kedarnath, Gangotri, and Yamunotri – are not just mere destinations; they're gateways to the soul.
#
# In a small village at the foot of the Himalayas, there lived a young boy named Rohan. He was an ardent devotee of Lord Shiva, and his heart yearned to embark on the Char Dham Yatra, a pilgrimage to the four sacred shrines. Rohan's parents, though poor, encouraged his spiritual quest, and with the blessings of the village elder, he set out on his journey.
#
# ...

# %%
print(ai_router("Identify this monument", "tajmahal.jpg"))
# Out:
# Detected intent: general
# Namaste! I'd be happy to help you identify the monument. However, I don't see an image or description of the monument. Could you please provide more information or context about the monument you're referring to?
#
# Is it a temple, a fort, a statue, or something else? Is it located in a specific region of India, such as the Himalayas, the plains of North India, or the southern states?
#
# If you provide more details, I'll do my best to help you identify the monument and share its cultural and historical significance with you.
#
# Perhaps it's one of the Char Dham sites, such as Badrinath, Kedarnath, Gangotri, or Yamunotri? Or maybe it's a famous landmark like the Taj Mahal or the Red Fort? Let me know, and I'll be happy to guide you through the rich history and mythology of India!

# %%
ai_router("Best places to visit in Pithoraghar?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Best places to hotel in Mumbai?")
# Out:
# Detected intent: tourism
# {'location': 'best places to  in mumbai?',
#  'hotels': ['Hotel Sunshine — ₹1200/night in best places to  in mumbai?',
#   'Himalayan View Homestay — ₹850/night in best places to  in mumbai?',
#   'Eco Retreat Camp — ₹950/night in best places to  in mumbai?'],
#  'eco_rating': 'All listed stays follow sustainable tourism guidelines.'}

# %%
ai_router("What are the best places to visit in Uttarakhand in December?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Suggest a 3-day itinerary for Jaipur")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("How many days are enough for Goa?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Is Kedarnath open in February?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("What are the safest solo-travel places in India?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Suggest eco-friendly trekking options near Rishikesh.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("How can I reach Badrinath from Delhi?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("What is the best time to visit Valley of Flowers?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Recommend homestays near Munsiyari.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Tell me budget trip places in South India.")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Give me a sustainable tourism plan for Char Dham Yatra.")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Compare crowd levels of Kedarnath, Badrinath, and Gangotri in June")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Plan a family-friendly spiritual + nature itinerary for 7 days.")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("Suggest AI-based travel optimization for a high-altitude trek.")
# Out:
# Detected intent: tourism
# {'location': 'suggest ai-based travel optimization for a high-altitude .',
#  'route_condition': 'Trail is open and safe.',
#  'altitude_warning': 'Stay hydrated. Avoid rapid ascent.',
#  'weather_risk': 'Low wind, clear visibility.',
#  'recommended_gear': 'Warm layers, trekking pole, torch.',
#  'source': 'Deep-Shiva Trek Route API (demo)'}

# %%
ai_router("What are cultural etiquettes visitors must follow in Jagannath Puri?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("Give a Sanskrit shloka about courage and explain its meaning.")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("How does Hindu philosophy view suffering?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Explain the mythology behind Panch Kedar.")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("Weather in Rishikesh tomorrow morning?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Suggest affordable hotels near Lohaghat.")
# Out:
# Detected intent: general
# ...

# %%
output = ai_router("Explain shloka 2.47 of Bhagavad Gita")

with open("output.txt", "w", encoding="utf-8") as f:
    f.write(str(output))

output
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("Weather in Rishikesh tomorrow morning?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Is it raining in Gangotri today?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Suggest affordable hotels near Jageshwar.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("I feel stressed. Suggest something peaceful in Uttarakhand.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Give me a local Uttarakhand diet plan.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Suggest a yoga routine for back pain.")
# Out:
# Detected intent: yoga
# 'Please upload a yoga pose image.'

# %%
ai_router("Provide a breathing technique to improve focus.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("अध्यात्म के लिए एक श्लोक सुनाइए।")
# Out:
# Detected intent: general
# 'अध्यात्म के लिए एक श्लोक है:\n\n"अस्तो मा सद्गमय,\nतमसो मा ज्योतिर्गमय,\nमृत्योर्मा अमृतं गमय।"\n\nइसका अर्थ है:\n"मुझे असत्य से सत्य की ओर ले जाइए,\nअंधकार से प्रकाश की ओर ले जाइए,\nमृत्यु से अमृत की ओर ले जाइए।"\n\nयह श्लोक हमें अध्यात्म के मार्ग पर आगे बढ़ने के लिए प्रेरित करता है और हमें सत्य, प्रकाश, और अमृत की ओर ले जाने की प्रार्थना करता है।'

# %%
ai_router("मानसून में केदारनाथ सुरक्षित है क्या?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Recommend local food for high-energy trekking.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Explain the symbolism of Shiva in meditation.")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Tell me a motivational quote.")
# Out:
# Detected intent: general
# 'Namaste, my friend. I\'d like to share with you a powerful quote from the Bhagavad Gita: "Karmanye vadhikaraste, Ma Phaleshu Kadachana" (कर्मण्येवाधिकारस्ते, मा फलेषु कदाचन). \n\nThis translates to: "You have a right to perform your actions, but never to the fruits of your actions." It reminds us to focus on our efforts, not the outcome, and to trust that the universe will take care of the rest. May this inspire you to embark on your journey with courage and determination.'

# %%
ai_router("Translate this into Hindi: “The mountains are calling.”")
# Out:
# Detected intent: general
# 'पहाड़ पुकार रहे हैं। (Pahad pukar rahe hain)\n\nOr, in a more poetic way: \nपर्वत पुकारते हैं (Parvat pukarte hain)\n\nThis phrase is often used to evoke a sense of adventure and connection with nature, much like the famous phrase by John Muir, which inspired the translation.'

# %%
ai_router("I want a peaceful trip, prefer cold weather, love mythology, and have low budget. Suggest a perfect destination")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("I scanned a QR code at a temple — explain the mythology of this place.")
# Out:
# Detected intent: spiritual
# ...

# %%
ai_router("Low buget hotels in pithoraghar")
# Out:
# Detected intent: general
# ...

# %%
ai_router("High buget hotels in pithoraghar")
# Out:
# Detected intent: general
# ...

# %%
ai_router("chakrata snowfall time?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("hidden place near kimadi")
# Out:
# Detected intent: tourism
# 'Cherrapunji mein kimadi ke paas ek gupt sthal hai, jo ki ek prakriti premiyon ka sapna hai. Yeh sthal hai Mawsmai Cave, jo ki kimadi se lagbhag 10 kilometer door hai. Yeh gufa apni prakritik sundarta aur adbhut chattrakaron ke liye prasiddh hai.\n\nMawsmai Cave ek limestone cave hai, jo ki Meghalaya ki vishishtata hai. Is gufa mein aapko kayi tarah ke chattrakar, jaise ki stalagmite aur stalactite, dekhne ko milenge. Iske alawa, yeh gufa apni andheri aur thandi hawa ke liye bhi prasiddh hai.\n\nYadi aap kimadi ke paas hain aur Mawsmai Cave jana chahte hain, to aap taxi ya bus se yahaan pahunche sakte hain. Yeh gufa subah 9:30 baje se shaam 4:30 baje tak khula rehta hai.\n\nEco-tip: Mawsmai Cave ke aaspaas ke kshetra mein plastic ka upyog na karein, aur apne saath lekar aaye huye kachre ko wapas le jaayein.\n\nSource: tour_69, tour_29, tour_109'

# %%
ai_router("Tomarrow weather of dehradun")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Best honeymoon places in india")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("best place in keral to vist")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("best place in keral to visit in english")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("best place in paris")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("srinagar")
# Out:
# Detected intent: general
# ...

# %%
ai_router("honey spot in india")
# Out:
# Detected intent: general
# ...

# %%
ai_router("ladak trip")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("How does your bot decide between RAG answer and live API answer for tourism queries?")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("How does your bot decide between RAG answer and live API answer for tourism queries? in english")
# Out:
# Detected intent: tourism
# ...

# %%
ai_router("How do you ensure correct grammar when switching Hindi ↔ English ↔ Sanskrit?")
# Out:
# Detected intent: general
# ...

# %%
ai_router("Gives nearest hospital, police station, helpline numbers near sudhowala dehradun")
# Out:
# Detected intent: general
# ...

# %%
ai_router("cafe near sudhowala")
# Out:
# Detected intent: general
# ...

# %%
ai_router("university near sudhowala")
# Out:
# Detected intent: general
# ...

# %%
ai_router("review of uttarakhand technical university")
# Out:
# Detected intent: general
# ...

# %%
ai_router("lohaghat famous fruit")
# Out:
# Detected intent: general
# ...

# %%
ai_router("famous sweet of lucknow")
# Out:
# Detected intent: general
# 'Namaste! Lucknow, the city of nawabs, is not only famous for its rich history and cultural heritage, but also for its delectable sweets. One of the most famous sweets of Lucknow is the "Malai Gilori". It\'s a sweet, flaky pastry filled with a rich, creamy mixture of malai (clotted cream), khoya, and nuts. The Malai Gilori is a specialty of Lucknow and is often served at special occasions and festivals.\n\nAnother popular sweet of Lucknow is the "Chaat ka Samosa", but if I had to pick one traditional sweet, I would say it\'s the "Malai Gilori". Would you like to know more about the best places to try these sweets in Lucknow or perhaps some recommendations for a sweet-tooth satisfying itinerary?'

# %%
ai_router("agar famous sweet")
# Out:
# Detected intent: general
# ...

# %%
ai_router("kolkta famous sweet")
# Out:
# Detected intent: general
# ...

# %%
ai_router("famous things to eat in meerut")
# Out:
# Detected intent: general
# ...

# %%
pip install gtts playsound
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7043 sha256=71ef4e2e454dc27741da5c276f57a779a63f6918e4d3e175d810c78ea5681d23
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\d6\f5\4a\73cfe233d9749e0a05fe8d6200a961cd12a8535556b2e582d7
# Successfully built playsound
# ...
#
#    ---------------------------------------- 2/2 [gtts]
#
# ...
#   DEPRECATION: Building 'playsound' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'playsound'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import playsound
print("Playsound is installed and working!")
# Out:
# Playsound is installed and working!

# %%
pip install SpeechRecognition pyaudio
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
# ...

# %%
pip install openai-whisper
# Out:
# ...
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
# ...

# %%
pip install sounddevice scipy
# Out:
# ...
#   Using cached sounddevice-0.5.3-py3-none-win_amd64.whl.metadata (1.6 kB)
# ...
# Using cached sounddevice-0.5.3-py3-none-win_amd64.whl (364 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install SpeechRecognition
# !pip install gTTS
# !pip install playsound==1.2.2
# !pip install PyAudio
# Out:
# ...
#   Attempting uninstall: playsound
#     Found existing installation: playsound 1.3.0
#     Uninstalling playsound-1.3.0:
#       Successfully uninstalled playsound-1.3.0
# ...

# %%
from voice_engine import listen_user

listen_user()
# Out:
# 🎤 Speak now…
# 'I could not understand. Please repeat.'

# %%
from voice_output import speak
speak("Hello! Voice output is working perfectly now.")

# %%
from voice_output import speak
speak("Hello! Voice output is working perfectly now.")

# %%
from voice_output import speak
speak("Hello Shubhi! Your tourism chatbot voice output is working perfectly.")
# Out:
#     Error 263 for command:
#         close voice_b04d6b9e-ec48-45a9-8cce-50c27d16c48b.mp3
#     The specified device is not open or is not recognized by MCI.
# Failed to close the file: voice_b04d6b9e-ec48-45a9-8cce-50c27d16c48b.mp3

# %%
# !pip install pydub
# Out:
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# ...

# %%
import os
os.environ["FFMPEG_BINARY"] = r"C:\ffmpeg-7.1.1-full_build\bin\ffmpeg.exe"
os.environ["FFPROBE_BINARY"] = r"C:\ffmpeg-7.1.1-full_build\bin\ffprobe.exe"

# %%
from voice_output import speak
speak("Hello! Voice output is working correctly now.")

# %%
from router import ai_router
from voice_output import speak

answer = ai_router("Best places to visit in Dehradun?")
print(answer)
speak(answer)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Detected intent: tourism
# Dehradun, the capital city of Uttarakhand, is a beautiful destination with a mix of natural beauty, culture, and adventure. Here are some of the best places to visit in Dehradun:
#
# 1. **Robber's Cave** (Source: tour_93): A natural cave with a river flowing through it, perfect for a day trip.
# 2. **Mindrolling Monastery** (Source: tour_83): A beautiful Buddhist monastery with stunning architecture and peaceful surroundings.
# 3. **Forest Research Institute** (Source: tour_103): A historic institution with a beautiful campus, known for its architectural grandeur and educational significance.
# ...

# %%
from voice_output import speak
speak("नमस्ते! मैं आपकी मदद के लिए तैयार हूँ।")

# %%
from router import ai_router
from voice_output import speak

answer = ai_router("देहरादून में घूमने की सबसे अच्छी जगहें कौन सी हैं?")
print(answer)

# Speak in Hindi
speak(answer, lang="hi")
# Out:
# Detected intent: general
# नमस्ते! देहरादून एक सुंदर शहर है, जो हिमालय की तलहटी में बसा हुआ है। यहाँ की प्राकृतिक सुंदरता, संस्कृति, और आध्यात्मिक महत्व को देखने के लिए कई आकर्षक स्थल हैं। देहरादून में घूमने की सबसे अच्छी जगहें हैं:
#
# 1. **मसूरी**: देहरादून से लगभग 35 किलोमीटर दूर, मसूरी एक प्रसिद्ध हिल स्टेशन है, जो अपनी प्राकृतिक सुंदरता और शांत वातावरण के लिए जाना जाता है।
# 2. **राजाजी नेशनल पार्क**: यह राष्ट्रीय उद्यान देहरादून के पास स्थित है, जो अपने वन्य जीवन और प्राकृतिक सुंदरता के लिए प्रसिद्ध है।
# 3. **साहसी धारा**: यह एक सुंदर झरना है, जो देहरादून के पास स्थित है। यहाँ का पानी बहुत ठंडा और स्वच्छ है।
# 4. **तपकेश्वर मंदिर**: यह एक प्रसिद्ध शिव मंदिर है, जो देहरादून में स्थित है। यहाँ का प्रमुख आकर्षण है एक प्राकृतिक गुफा, जिसमें शिवलिंग स्थापित है।
# 5. **फॉरेस्ट रिसर्च इंस्टीट्यूट (एफआरआई)**: यह एक प्रसिद्ध संस्थान है, जो वनस्पति विज्ञान और वन्य जीवन के अध्ययन के लिए जाना जाता है।
# ...
