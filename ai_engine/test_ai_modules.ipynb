# %%
from router import ai_router
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
ai_router("what is the significance of Kedarnath?")
# Out:
# {'status': 'ok',
#  'intent': 'spiritual',
# ...

# %%
ai_router("কেদারনাথ মন্দিরের গুরুত্ব কী?")
# Out:
# {'status': 'ok',
#  'intent': 'spiritual',
# ...

# %%
ai_router("केदारनाथ मंदिराचे महत्त्व काय आहे?")
# Out:
# {'status': 'ok',
#  'intent': 'spiritual',
# ...

# %%
ai_router("केदारनाथ का धार्मिक महत्व क्या है?")
# Out:
# {'status': 'ok',
#  'intent': 'general',
# ...

# %%
ai_router("Give a Bhagavad Gita shloka about duty")
# Out:
# {'status': 'ok',
#  'intent': 'spiritual',
# ...

# %%
ai_router("গীতার একটি শ্লোক বলুন")
# Out:
# {'status': 'ok',
#  'intent': 'general',
#  'answer': 'I am SHIVA BOT — your Tourism & Spiritual assistant.\n\n"You have a right to perform your prescribed duties, but never to the fruits of action. Never consider yourself to be the cause of the results of your activities, and never be attached to not doing your duty." - Bhagavad Gita (Chapter 2, Verse 47)',
#  'lang': 'en'}

# %%
ai_router("गीतेतील एक श्लोक सांगा")
# Out:
# {'status': 'ok',
#  'intent': 'spiritual',
#  'answer': 'I am SHIVA BOT — your Tourism & Spiritual assistant.\n\nएक पवित्र श्लोक आहे जो भगवद्गीतेतील १२व्या अध्यायातील १५वा श्लोक आहे:\n\nसंस्कृत: यस्मान्नोद्विजते लोको लोकान्नोद्विजते च यः |\nहिंदी अर्थ: जिससे लोग परेशान नहीं होते और जो स्वयं भी लोगों से परेशान नहीं होता |\nइंग्लिश अर्थ: One who neither disturbs others nor is disturbed by them is dear to Me.\n\nध्यान प्रेरक: "मी शांति आणि प्रेमाचा सागर आहे, जो इतरांना किंवा माझ्यावर कोणताही परिणाम न ठेवता निर्मल आणि शांत राहतो."',
#  'lang': 'en'}

# %%
ai_router("Where is the nearest toilet in Sudhowala?")
# Out:
# {'status': 'ok',
#  'intent': 'toilet',
#  'answer': {'status': 'fallback',
#   'toilets': [{'name': 'Public Toilet (Municipal)', 'note': 'Near main road'},
#    {'name': 'Pay & Use Toilet', 'note': 'Near market'}]},
#  'lang': 'en'}

# %%
ai_router("Toilet in Dehradun clock tower?")
# Out:
# {'status': 'ok',
#  'intent': 'toilet',
#  'answer': {'status': 'ok',
#   'center': {'lat': '30.3243226', 'lon': '78.0418634'},
#   'toilets': [{'name': 'Public Toilet', 'lat': 30.3342572, 'lon': 78.0329081},
#    {'name': 'Public Toilet', 'lat': 30.3342549, 'lon': 78.0329269},
#    {'name': 'Public Toilet', 'lat': 30.3264082, 'lon': 78.0449227},
#    {'name': 'Public Toilet', 'lat': 30.3245935, 'lon': 78.0461072},
#    {'name': 'Public Toilet', 'lat': 30.3233808, 'lon': 78.0443532},
#    {'name': 'Public Toilet', 'lat': 30.3158028, 'lon': 78.0335203}]},
#  'lang': 'en'}

# %%
ai_router("Weather in Kedarnath")
# Out:
# {'status': 'ok',
#  'intent': 'weather',
#  'answer': {'status': 'ok',
#   'location': 'Kedarnath',
#   'temperature': '9.97°C',
#   'condition': 'Overcast Clouds',
#   'humidity': '70%'},
#  'lang': 'en'}

# %%
ai_router("কেদারনাথের আবহাওয়া")
# Out:
# {'status': 'ok',
#  'intent': 'tourism',
#  'answer': 'I am SHIVA BOT — your Tourism & Spiritual assistant.\n\nকেদারনাথের আবহাওয়া সাধারণত শীতল থাকে। এখানকার আবহাওয়া বছরের বিভিন্ন সময়ে বিভিন্ন রকম হয়ে থাকে।\n\nগ্রীষ্মকালে (মে-জুন), কেদারনাথের তাপমাত্রা ১৫-২০ ডিগ্রি সেলসিয়াস থাকে। এটি এখানে ভ্রমণের জন্য সেরা সময়।\n\nশীতকালে (ডিসেম্বর-ফেব্রুয়ারি), কেদারনাথের তাপমাত্রা ০-১০ ডিগ্রি সেলসিয়াস থাকে। এসময় এখানে তুষারপাত হয়।\n\nবর্ষাকালে (জুলাই-সেপ্টেম্বর), কেদারনাথের তাপমাত্রা ১০-১৫ ডিগ্রি সেলসিয়াস থাকে। এসময় এখানে ভারী বর্ষণ হয়।\n\nযদি আপনি কেদারনাথে ভ্রমণের পরিকল্পনা করছেন, তাহলে আপনাকে আবহাওয়ার পূর্বাভাস দেখে নেওয়া উচিত। এছাড়াও, আপনাকে আপনার পরিবেশের প্রতি সচেতন থাকতে হবে এবং পরিবেশ রক্ষার জন্য প্রয়োজনীয় ব্যবস্থা নিতে হবে।\n\nএকটি ইকো-টিপ: কেদারনাথে ভ্রমণের সময়, আপনাকে প্লাস্টিকের ব্যবহার কমাতে হবে এবং পরিবেশের সুরক্ষার জন্য প্রয়োজনীয় ব্যবস্থা নিতে হবে।',
#  'lang': 'en'}

# %%
ai_router("केदारनाथ में सस्ता होटल")
# Out:
# {'status': 'ok',
#  'intent': 'tourism',
# ...

# %%
ai_router("I feel stressed")
# Out:
# {'status': 'ok',
#  'intent': 'general',
#  'answer': "I am SHIVA BOT — your Tourism & Spiritual assistant.\n\nI'm here to help. Stress can be overwhelming, but there are ways to manage it. Would you like to talk about what's causing your stress? Sometimes sharing your feelings can help you feel better. I'm listening. \n\nAdditionally, I can suggest some stress-reducing techniques if you'd like. We could explore options like deep breathing, meditation, or physical activity. What do you think?",
#  'lang': 'en'}

# %%
ai_router("केदारनाथमध्ये गर्दी")
# Out:
# {'status': 'ok',
#  'intent': 'tourism',
# ...

# %%
ai_router("Eco friendly travel tips for trekking")
# Out:
# {'status': 'ok',
#  'intent': 'tourism',
# ...

# %%
from router import ai_router

# Path to your monument image
IMAGE_PATH = "taj_mahal.webp"

# Test query
query = "Identify this monument"

# Run AI router
result = ai_router(
    user_input=query,
    image_path=IMAGE_PATH
)

# Print result
print("🧾 Query:", query)
print("🖼 Image:", IMAGE_PATH)
print("🎯 Intent:", result.get("intent"))
print("🌐 Language:", result.get("lang"))
print("📍 Result:", result.get("answer"))
# Out:
# 🧾 Query: Identify this monument
# 🖼 Image: taj_mahal.webp
# 🎯 Intent: monument
# 🌐 Language: en
# 📍 Result: {'monument': 'Taj Mahal', 'confidence': 97.35, 'raw_score': 0.9734626412391663}

# %%
from router import ai_router
ai_router("Check my yoga posture", image_path="pose1.jpg")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY
# {'status': 'ok',
#  'intent': 'yoga',
#  'answer': {'pose': 'Pose detected successfully!'},
#  'lang': 'en'}

# %%
from router import ai_router

tests = [
    "Start meditation",
    "Guide me in meditation",
    "ध्यान शुरू करें",
    "मला ध्यान करायचे आहे",
    "আমি ধ্যান করতে চাই"
]

for q in tests:
    print("\n🧾 Query:", q)
    res = ai_router(q)
    print("🎯 Intent:", res["intent"])
    print("🌐 Language:", res["lang"])
    print("🧘 Answer:", res["answer"])
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY
#
# 🧾 Query: Start meditation
# 🎯 Intent: yoga
# 🌐 Language: en
# 🧘 Answer: Upload yoga pose image.
#
# 🧾 Query: Guide me in meditation
# 🎯 Intent: yoga
# 🌐 Language: en
# 🧘 Answer: Upload yoga pose image.
#
# 🧾 Query: ध्यान शुरू करें
# 🎯 Intent: yoga
# 🌐 Language: en
# 🧘 Answer: Upload yoga pose image.
#
# 🧾 Query: मला ध्यान करायचे आहे
# 🎯 Intent: yoga
# 🌐 Language: en
# 🧘 Answer: Upload yoga pose image.
#
# 🧾 Query: আমি ধ্যান করতে চাই
# 🎯 Intent: yoga
# 🌐 Language: en
# 🧘 Answer: Upload yoga pose image.

# %%
ai_router("Check my yoga posture", image_path="pose1.jpg")
# Out:
# {'status': 'ok',
#  'intent': 'yoga',
#  'answer': {'pose': 'Pose detected successfully!'},
#  'lang': 'en'}

# %%
import requests
print(requests.post(
    "http://127.0.0.1:5005/predict",
    files={"image": open("pose1.jpg", "rb")}
).json())
# Out:
# {'pose': 'Pose detected successfully!'}

# %%
from meditation_engine import generate_meditation_audio

result = generate_meditation_audio(
    duration_sec=20,
    ambience="forest",
    language="en",
    script_text="Breathe deeply. Relax your shoulders. Let your mind settle like still water."
)

print(result)
# Out:
# {'status': 'ok', 'message': 'Meditation (20s) with forest ambience started.', 'language': 'en'}

# %%
from meditation_engine import generate_meditation_audio

result = generate_meditation_audio(
    duration_sec=20,
    ambience="forest",
    language="en",
    script_text="Breathe deeply. Relax your shoulders. Let your mind settle like still water."
)

print(result)
# Out:
# {'status': 'ok', 'message': 'Meditation (20s) with forest ambience started.', 'language': 'en'}

# %%
ai_router("Check my yoga posture", image_path="pose1.jpg")
# Out:
# {'status': 'ok',
#  'intent': 'yoga',
#  'answer': {'pose': 'Yoga service offline',
#   'feedback': ['✘ Yoga AI service is not running.',
#    '✔ Please start yoga_server.py and try again.']},
#  'lang': 'en'}

# %%
import requests

print(
    requests.get("http://127.0.0.1:5005").status_code
)
# Out:
# 404

# %%
import requests

with open("pose1.jpg", "rb") as f:
    r = requests.post(
        "http://127.0.0.1:5005/predict",
        files={"image": f},
        timeout=5
    )

print(r.json())
# Out:
# {'pose': 'Pose detected successfully!'}

# %%
from router import ai_router

print(
    ai_router("Check my yoga posture", image_path="pose1.jpg")
)
# Out:
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Pose detected successfully!'}, 'lang': 'en'}

# %%
from intent_classifier import classify_intent

tests = [
    "Start meditation",
    "I want yoga posture check",
    "ध्यान शुरू करें",
    "योग आसन जांचें",
    "আমি ধ্যান করতে চাই",
    "Check my yoga posture"
]

for t in tests:
    print(t, "→", classify_intent(t))
# Out:
# Start meditation → yoga
# I want yoga posture check → yoga
# ध्यान शुरू करें → yoga
# योग आसन जांचें → yoga
# আমি ধ্যান করতে চাই → yoga
# Check my yoga posture → yoga

# %%
print(
    ai_router("Check my yoga posture", image_path="pose1.jpg")
)
# Out:
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Pose detected successfully!'}, 'lang': 'en'}

# %%
import requests
print(
    requests.post(
        "http://127.0.0.1:5005/predict",
        files={"image": open("pose1.jpg", "rb")}
    ).json()
)
# Out:
# {'pose': 'Pose detected successfully!'}

# %%
from router import ai_router
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Pose detected successfully!'}, 'lang': 'en'}

# %%
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Pose detected successfully!'}, 'lang': 'en'}

# %%
from router import ai_router
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Pose detected successfully!'}, 'lang': 'en'}

# %%
from ai_router import ai_router
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# ⚠️ Dataset missing: kumaoni_full_5000.csv — skipping load
# ⚠️ Dataset missing: garhwali_full_5000.csv — skipping load
# 🔥 THIS ai_router.py IS EXECUTING
# {'status': 'ok', 'intent': 'yoga', 'lang': 'en', 'answer': {'pose': 'Pose detected', 'feedback': ['✔ Yoga posture detected', '✔ Detailed posture feedback unavailable (legacy response blocked)']}}

# %%
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# {'status': 'ok', 'intent': 'yoga', 'lang': 'en', 'answer': {'pose': 'Pose detected', 'feedback': ['✔ Yoga posture detected', '✔ Detailed posture feedback unavailable (legacy response blocked)']}}

# %%
import requests

r = requests.post(
    "http://127.0.0.1:5005/predict",
    files={"image": open("pose1.jpg", "rb")}
)

print(r.json())
# Out:
# {'pose': 'Pose detected successfully!'}

# %%
from router import ai_router
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Yoga service offline', 'feedback': ['✘ Yoga AI service is not running.', '✔ Please start yoga_server.py and try again.']}, 'lang': 'en'}

# %%
from meditation_engine import generate_meditation_audio

result = generate_meditation_audio(
    duration_sec=20,
    ambience="forest",
    language="en",
    script_text="Breathe deeply. Relax your shoulders. Let your mind settle like still water."
)

print(result)
# Out:
# {'status': 'ok', 'message': 'Meditation (20s) with forest ambience started.', 'language': 'en'}

# %%
print(ai_router("Check my yoga posture", image_path="pose1.jpg"))
# Out:
# {'status': 'ok', 'intent': 'yoga', 'answer': {'pose': 'Yoga service offline', 'feedback': ['✘ Yoga AI service is not running.', '✔ Please start yoga_server.py and try again.']}, 'lang': 'en'}

# %%
{
  "place": "Kedarnath",
  "shloka": "अहं सर्वस्य प्रभवः",
  "meaning": "I am the source of all creation"
}
# Out:
# {'place': 'Kedarnath',
#  'shloka': 'अहं सर्वस्य प्रभवः',
#  'meaning': 'I am the source of all creation'}

# %%
{
  "map_mode": "offline",
  "note": "Showing cached route from Gaurikund to Kedarnath"
}
# Out:
# {'map_mode': 'offline',
#  'note': 'Showing cached route from Gaurikund to Kedarnath'}

# %%
{
  "washroom": "GMVN Public Toilet",
  "distance": "200m",
  "open": "Yes"
}
# Out:
# {'washroom': 'GMVN Public Toilet', 'distance': '200m', 'open': 'Yes'}

# %%
FAQ = {
  "kedarnath": "Kedarnath is one of the 12 Jyotirlingas of Lord Shiva."
}

# %%
from yoga_client import detect_yoga

detect_yoga("pose1.jpg")
# Out:
# {'pose': 'Yoga service offline',
#  'feedback': ['✘ Yoga AI service is not running.',
#   '✔ Please start yoga_server.py and try again.']}

# %%
{
  "pose": "Tree_Pose_or_Vrksasana_",
  "confidence": 0.87,
  "feedback": [
    "🧘 Pose identified: Tree Pose",
    "📊 Confidence: 87.00%"
  ]
}
# Out:
# {'pose': 'Tree_Pose_or_Vrksasana_',
#  'confidence': 0.87,
#  'feedback': ['🧘 Pose identified: Tree Pose', '📊 Confidence: 87.00%']}

# %%
import requests

url = "http://127.0.0.1:5005/predict"

with open("pose1.jpg", "rb") as f:
    files = {"image": f}
    response = requests.post(url, files=files)

print("Status:", response.status_code)
print("Raw response:", response.text)
# Out:
# Status: 200
# Raw response: {
#   "feedback": [
#     "\u274c Model inference failed"
#   ],
#   "pose": "Error"
# }

# %%
import requests

url = "http://127.0.0.1:5005/predict"
with open("pose1.jpg", "rb") as f:
    r = requests.post(url, files={"image": f})

print(r.status_code)
print(r.json())
# Out:
# 200
# {'confidence': 0.5, 'feedback': ['🧘 Pose detected: Akarna Dhanurasana', '⚠️ Running in TFLite fallback mode (Windows-safe)'], 'pose': 'Akarna_Dhanurasana'}

# %%
from router import ai_router
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY

# %%
ai_router("what is the significance of kedarnath")
# Out:
# {'status': 'ok',
#  'intent': 'spiritual',
# ...

# %%
from yoga_client import detect_yoga

detect_yoga("pose1.jpg")
# Out:
# {'pose': 'Yoga service offline',
#  'feedback': ['✘ Yoga AI service is not running.',
#   '✔ Please start yoga_server.py and try again.']}

# %%
from router import ai_router

# Path to your monument image
IMAGE_PATH = "taj_mahal.webp"

# Test query
query = "Identify this monument"

# Run AI router
result = ai_router(
    user_input=query,
    image_path=IMAGE_PATH
)

# Print result
print("🧾 Query:", query)
print("🖼 Image:", IMAGE_PATH)
print("🎯 Intent:", result.get("intent"))
print("🌐 Language:", result.get("lang"))
print("📍 Result:", result.get("answer"))
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔥 USING UPDATED YOGA_CLIENT.PY
# 🧾 Query: Identify this monument
# 🖼 Image: taj_mahal.webp
# 🎯 Intent: monument
# 🌐 Language: en
# 📍 Result: {'monument': 'Taj Mahal', 'confidence': 97.35, 'raw_score': 0.9734626412391663}

# %%
{
  "pose": "Tree_Pose_or_Vrksasana_",
  "confidence": 0.87,
  "feedback": [
    "🧘 Pose identified: Tree Pose",
    "📊 Confidence: 87.00%"
  ]
}
# Out:
# {'pose': 'Tree_Pose_or_Vrksasana_',
#  'confidence': 0.87,
#  'feedback': ['🧘 Pose identified: Tree Pose', '📊 Confidence: 87.00%']}

# %%
from router import ai_router

# Path to your monument image
IMAGE_PATH = "taj_mahal.webp"

# Test query
query = "Identify this monument"

# Run AI router
result = ai_router(
    user_input=query,
    image_path=IMAGE_PATH
)

# Print result
print("🧾 Query:", query)
print("🖼 Image:", IMAGE_PATH)
print("🎯 Intent:", result.get("intent"))
print("🌐 Language:", result.get("lang"))
print("📍 Result:", result.get("answer"))
# Out:
# 🧾 Query: Identify this monument
# 🖼 Image: taj_mahal.webp
# 🎯 Intent: monument
# 🌐 Language: en
# 📍 Result: {'monument': 'Taj Mahal', 'confidence': 97.35, 'raw_score': 0.9734626412391663}
